# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\bagan\Downloads\E-commerce\ecommerce_dataset\Blinkit\Blinkit Data.csv")

# %%
print(df)

# %%
df.columns

# %%
df.info()

# %%
df.isnull().sum()

# %%
df['Item_Weight'] = df['Item_Weight'].fillna(df['Item_Weight'].mean())

# %%
df.head(10)

# %%
df.tail(10)

# %%
print("size of Data:",df.shape)

# %%
df.dtypes

# %%
print(df['Item_Fat_Content'].unique())

# %%
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({'LF':'Low Fat',
                                                         'low fat':'Low Fat',
                                                         'reg' : 'Regular'})

# %%
print(df['Item_Fat_Content'].unique())

# %%
total_sales =df['Total_Sales'].sum()
avg_sales = df['Total_Sales'].mean() 
no_of_items_sold = df['Item_Identifier'].count()
avg_rating = df['Rating'].mean()

print(f"Total Sales: ${total_sales:,.0f}")
print(f"Average Sales: ${avg_sales:,.0f}")
print(f"No of items sold: {no_of_items_sold:,.0f}")
print(f"Average Rating: {avg_rating:,.1f}")

# %%
sales_by_item = df.groupby('Item_Type')['Total_Sales'].sum().sort_values(ascending=False)
bars = sales_by_item.plot(kind='bar', figsize=(10,5))
plt.title("Sales by Items")
for bar in bars.patches:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
            f'{bar.get_height():,.0f}', ha='center', va='bottom', fontsize=8)
plt.tight_layout()
plt.show()

print("""
Fruits & Vegetables and Snack Foods contributed the highest sales, showing strong customer demand for daily consumable products.
""")

# %%
sales_by_year = df.groupby('Outlet_Establishment_Year') ['Total_Sales'].sum().sort_index() 

plt.figure(figsize=(9,5)) 
plt.plot(sales_by_year.index, sales_by_year.values, marker='o', linestyle='-') 

plt.xlabel('Outlet Establishment Year') 
plt.ylabel('Total Sales') 
plt.title('Outlet Establishment') 

for x, y in zip(sales_by_year.index, sales_by_year.values): 
    plt.text(x, y, f'{y:,.0f}', ha='center', va='bottom', fontsize=8) 
    
plt.tight_layout() 
plt.show()

print("""
Sales remained relatively stable between 2012 and 2017, followed by a significant peak in 2018. This indicates that outlets established in 2018 performed exceptionally well compared to other years.
""")

# %%
tier_sales = df.groupby('Outlet_Location_Type')['Total_Sales'].sum()
plt.figure(figsize=(4,4))
plt.pie(tier_sales,labels=tier_sales.index,autopct='%1.1f%%',startangle = 90)
plt.title('Outlet_Location_Type')
plt.tight_layout()
plt.show()
print("""
Tier 3 outlets contribute highest sales.
""")

# %%
fat_sales = df.groupby('Item_Fat_Content')['Total_Sales'].sum()
plt.figure(figsize=(6,6))
plt.pie(
    fat_sales,
    labels=fat_sales.index,
    autopct='%1.1f%%',
    startangle=90,
    wedgeprops={'width':0.4}
)

plt.title("Sales by Fat Content")
plt.show()

print("""
Low Fat products contributed nearly 65% of total sales, significantly outperforming Regular products. This indicates a stronger customer preference for 
healthier food options.
""")

# %%
grouped = df.groupby(['Outlet_Location_Type','Item_Fat_Content'])['Total_Sales'].sum().unstack()
grouped = grouped[['Regular','Low Fat']]

ax = grouped.plot(
    kind='bar',
    figsize=(8,5),
    title='Outlet Tier by Item Fat Content',
    color=['#ff7f0e','#1f77b4'])
plt.xlabel('Outlet Location Tier')
plt.ylabel('Total Sales')
plt.legend(title='Item Fat Content')
plt.show()
print("""

Tier 3 outlets generated the highest sales for both Low Fat and Regular products, indicating stronger customer demand and better overall outlet performance in these regions.

Low Fat products consistently outperformed Regular products across all outlet tiers, showing a clear customer preference for healthier food options.
""")

# %%
rating_by_item = df.groupby('Item_Type')['Rating'].mean().sort_values()
plt.figure(figsize=(10,6))
sns.barplot(
    x=rating_by_item.values,
    y=rating_by_item.index
)
plt.title("Average Ratings by Item Type")
plt.xlabel("Average Rating")
plt.ylabel("Item Type")
plt.grid(axis='x', linestyle='--', alpha=0)
plt.show()
print("""
Average ratings across all item categories are consistently high, indicating overall positive customer satisfaction with Blinkit's products.
""")
